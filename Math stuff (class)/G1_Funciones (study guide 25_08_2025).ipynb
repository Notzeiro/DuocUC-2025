# %% [markdown]
# # Problema 1

# %%
def calc_datos(segundos):
    return 100 * segundos

print(f"En 45 segundos se transmiten: {calc_datos(45)} megabits")
print(f"En 1,5 minutos (90 segundos) se transmiten: {calc_datos(90)} megabits")
print(f"En 1 hora (3600 segundos) se transmiten: {calc_datos(3600)} megabits")
# Out:
# En 45 segundos se transmiten: 4500
# En 1,5 minutos (90 segundos) se transmiten: 9000
# En 1 hora (3600 segundos) se transmiten: 360000

# %% [markdown]
# Una red transmite datos a $100$ megabits por segundo. Crea una función utilizando *Python* que permita calcular la cantidad de datos transmitidos en una cierta cantidad de tiempo (en segundos). Luego utiliza la función y calcula cuántos datos se transmiten en:
#
# * $45$ segundos
# * $1,5$ minutos
# * $1$ hora

# %% [markdown]
# # Problema 2

# %%
def calc_datos(segundos):
    return 100 * segundos

for i in range (0 , 1001 , 100):
    print(calc_datos(i))
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000

# %% [markdown]
# Utilizando la función definida en el problema $1$, genera un listado que muestre los datos transmitidos para tiempos desde $0$ hasta $1.000$ segundos con incrementos de $100$ segundos.

# %% [markdown]
# # Problema 3

# %%
def calcular_latencia(milisegundos):
    return milisegundos * 1.2

print(f"La latencia real para 200 milisegundos es de: {calcular_latencia(200)}")
print(f"La latencia real para 149 milisegundos es de: {calcular_latencia(149)}")
print(f"La latencia real para 74 milisegundos es de: {calcular_latencia(74)}")
# Out:
# La latencia real para 200 milisegundos es de: 240.0
# La latencia real para 149 milisegundos es de: 178.79999999999998
# La latencia real para 74 milisegundos es de: 88.8

# %% [markdown]
# La **latencia** de una red corresponde al tiempo que tarda un paquete de datos en viajar desde el punto de origen al destino. En otras palabras, es el tiempo que transcurre desde que se envía una solicitud de un dispositivo hasta que se recibe una respuesta del servidor u otro dispositivo.
#
# La latencia puede verse afectada por la velocidad de transmisión de los datos a través de los cables o conexiones inalámbricas, la distancia física entre los dispositivos, el tiempo que tarda un computador en procesar o reenviar los datos, etc.
#
# En redes de comunicación, como las videoconferencias, juegos en línea y transmisión de datos en tiempo real, es deseable una baja latencia, de lo contrario pueden existir retrasos en la comunicación y afectar negativamente la experiencia del usuario.

# %% [markdown]
# Según el contexto mencionado, crea una función en *Python* que permita calcular la **latencia real** de una red dada una latencia estimada. Suponga que la latencia real es un $20\%$ mayor a la latencia estimada.
#
# Calcule la latencia real para una latencia estimada de:
#
# a)   $200$ milisegundos.
#
# b)   $149$ milisegundos.
#
# c)   $74$ milisegundos.

# %% [markdown]
# # Problema 4

# %%
def calcular_largo(horas):
    return ((horas*6600)/3567.57)
    

def calcular_horas(km):
    return ((km*3567.57)/6600)

#2) La variable dependiente seria el largo del cable y la independiente las horas
#3) El dominio contextualizado en ambas funciones seria un valor real positivo mayor a 0
#4) Se hara abajo:
import matplotlib.pyplot as plt
import numpy as np

x_values=np.linspace(1 , 3567 , 50)
y_values=calcular_largo(x_values)

plt.xlabel ("horas transcurridas")
plt.ylabel ("largo del cable en km")

plt.plot(x_values , y_values)

plt.show()

#5)
print(f"se instalaron {round(calcular_largo(148) , 2)} metros de cable al transcurrir 148 horas, \
al transcurrir 2300 horas se instalaron {round(calcular_largo(2300) , 2)}")
#6) Si se han instalado 3480km de cable han pasado:
print(f"Si se han instalado 3480 km de cable han pasado: {round (calcular_horas(3480) , 2)} horas")
#7) Para que se completara la obra(6600km) pasaron la siguiente cantidad de horas:
print(f"Para que se completara la obra(6600km) pasaron la siguiente cantidad de horas: {round(calcular_horas(6600) , 2)} ")
# Out:
# se instalaron 273.8 metros de cable al transcurrir 148 horas, al transcurrir 2300 horas se instalaron 4255.0
# Si se han instalado 3480 km de cable han pasado: 1881.08 horas
# Para que se completara la obra(6600km) pasaron la siguiente cantidad de horas: 3567.57

# %% [markdown]
# Como parte de un proyecto de mejora, en el año $2021$ se instaló un cable de fibra óptica que une España con EEUU. El cable tiene un largo de $6.600$ $km$ y fue colocado por un barco a una velocidad de $1,85$ $km/h$.
#
#
#
# 1.   Determine la forma algebraica de la función que permite determinar el largo del cable instalado (en km) a partir del tiempo transcurrido (en horas). Utilice la instrucción *def* para definir la función en *Python*.
# 2.   Defina variable dependiente e independiente, indicando unidad de medida.
# 3.   Determine el dominio contextualizado de la función.
# 4.   Grafique la función utilizando la biblioteca *Matplotlib* considerando el dominio contextualizado.
# 5.   ¿Cuántos metros de cable se instalaron al transcurrir $148$ horas? ¿Y transcurridas $2.300$ horas?
# 6.   Si se han instalado $3.480$ kilometros de cable, ¿cuántas horas llevan de trabajo?
# 7.   ¿Cuánto tiempo transcurrió para que se completara la obra?

# %% [markdown]
# # Problema 5

# %%
import matplotlib.pyplot as plt
import numpy as np

def calc_metro(t):
    return (t*0.4)

def calc_micro(t):
    return (t*0.3)


#Ejercicio 1:
x_values=np.linspace(1 , 10 , 10)
y_values=calc_metro(x_values)

plt.ylabel("Distancia en KM")
plt.xlabel("Tiempo en minutos")
plt.plot(x_values , y_values)
plt.show()
#ejercicio 2:
x_values=np.linspace(1 , 10 , 10)
y_values=calc_metro(x_values)

plt.ylabel("Distancia en KM")
plt.xlabel("Tiempo en minutos")
plt.plot(x_values , y_values)
plt.show()

#ejercicio 3:
#Para saber que metodo es mas util en terminos de tiempo para el turista utilizaremos
#ambas funciones para analizar cual usa menos tiempo

print(calc_metro(5))
print(calc_micro(5))

#al revisar ambos resultados podemos concluir que es mas conveniente para el turista usar micro
#en terminos de tiempo

#ejercicio 4:
print(f"Moneda hasta Tobalaba en metro: {round (calc_metro(6) , 2)} minutos")
print(f"Moneda hasta Tobalaba en micro: {round (calc_micro(6) , 2)} minutos")
# Out:
# 2.0
# 1.5
# Moneda hasta Tobalaba en metro: 2.4 minutos
# Moneda hasta Tobalaba en micro: 1.8 minutos

# %% [markdown]
# Un turista ha llegado a Santiago y desea conocer algunos lugares de la ciudad. Ha decidido visitar el Palacio de la Moneda y desde ahí trasladarse al centro comercial "Costanera Center", utilizando algún medio de transporte que ofrece la ciudad.
#
# Si se traslada en metro deberá abordar en estación La Moneda y bajar en la estación Tobalaba ($9$ estaciones). La función $f(t)$ permite calcular la distancia recorrida utilizando el metro (en kilómetros) transcurridos $t$ minutos.
#
# $$f(t) = 0,4t$$
#
# Si se traslada en bus, el turista podrá observar la ciudad y otros atractivos en su viaje. La función $g(t)$ permite calcular la distancia recorrida en bus (en kilómetros) transcurridos $t$ minutos.
#
# $$g(t) = 0,3t$$
#
# Según la información anterior:
#
# 1. Grafique ambas funciones, indicando el nombre de cada eje junto con su unidad de medida. Para realizar el gráfico utilice la biblioteca *Matplotlib*.
# 2.  Si se sabe que el metro se demora $1,2$ minutos en llegar desde una estación a otra y espera $30$ segundos en cada estación, indique el dominio contextualizado para $f(t)$.
# 3. Mediante análisis gráfico, indique cuál medio de transporte es más conveniente en términos de tiempo, para el turista. Justifique.
# 4.  Si se sabe que desde estación La Moneda hasta Tobalaba son aproximadamente $6$ kilómetros ¿cuántos tiempo tardará el turista en llegar a su destino con cada una de las opciones?

# %% [markdown]
# # Problema 6

# %%
import matplotlib.pyplot as plt
import numpy as np
# t = tiempo en horas

def calc_temp_serv(t):
    return ((-0.5*(t*t)) + (3*t) + 20)

print(f"En 9 horas, el servidor alcanza una temperatura de: {(round(calc_temp_serv(9) , 2))} c°")

#la variable independiente seria el tiempo ya que este ocurre simplemente(cuando el sv esta prendido)
#la variable dependiente seria la temperatura, esta depende del tiempo

#el dominio contextualizado serian todos los numeros realos mayores a 0, ya que el tiempo no puede ser negativo

x_values=np.linspace(1 , 9 , 9)
y_values=calc_temp_serv(x_values)

plt.xlabel("Tiempo en horas")
plt.ylabel("Temperatura en c°")
plt.plot(x_values , y_values)
plt.show()


print(f"la temperatura del servidor a las 13:00 es de : {calc_temp_serv(5)} c° \
      \ny la temperatura a las 17:00 es de {calc_temp_serv(9)} c°")
# Out:
# En 9 horas, el servidor alcanza una temperatura de: 6.5 c°
# la temperatura del servidor a las 13:00 es de : 22.5 c°
# y la temperatura a las 17:00 es de 6.5 c°

# %% [markdown]
# La temperatura de un servidor (en °C) puede ser modelada mediante la función
#
# $$T(t) = -0,5 t^{2} + 3 t + 20$$
#
# donde $t$ corresponde al tiempo transcurrido (en horas) en un día laboral. Considere que la jornada laboral comienza a las 08:00 horas y termina a las 17:00 horas.
#
# 1.  Defina variable dependiente e independiente, indicando unidad de medida.
# 2.  Determine el dominio contextualizado del problema.
# 3.  Grafique la función utilizando *Python*.
# 4.  Mediante un análisis gráfico, estime cuándo el servidor alcanza la máxima temperatura y calcule cuánto es.
# 5.  Determine la temperatura del servidor a las 13:00 horas y al finalizar la jornada laboral.

# %% [markdown]
# # Problema 7

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import numpy as np

# t = tiempo transcurrido en meses
def calc_num_usuarios(t):
    return 1000/ (1 + 9 * np.exp(-0.5 * t))

#la variable independiente seria el tiempo, en este caso en meses y la dependiente seria
#la cantidad de usuarios

print(f"la cantidad de usuarios transcurridos 12 meses sera de: {calc_num_usuarios(12)}")


x_values=np.linspace(1 , 12 , 12)
y_values=calc_num_usuarios(x_values)

plt.title("12 MESES")
plt.xlabel("Tiempo en meses")
plt.ylabel("Cantidad de usuarios en unidades")

plt.xticks(np.arange(1 , 13 , 1))

plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=False))
plt.ticklabel_format(style="plain" , axis="y")

plt.plot(x_values , y_values)
plt.show()

x_values=np.linspace(1 , 24 , 24)
y_values=calc_num_usuarios(x_values)

plt.title("2 AÑOS")
plt.xlabel("Tiempo en meses")
plt.ylabel("Cantidad de usuarios en unidades")

plt.xticks(np.arange(1 , 13 , 1))

plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=False))
plt.ticklabel_format(style="plain" , axis="y")

plt.plot(x_values , y_values)
plt.show()

#4)Para que la red social llegue a 800 usuarios deben pasar 8 meses aproximadamente
# Out:
# la cantidad de usuarios transcurridos 12 meses sera de: 978.178051236962

# %% [markdown]
# El número de usuarios de una red social se puede modelar mediante la función:
#
# $$U(t) = \frac{1.000}{1+9e^{-0.5t}}$$
#
# donde $t$ corresponde al tiempo transcurrido en meses.
#
# 1.  Defina variable dependiente e independiente, indicando unidad de medida.
# 2.  Determine la cantidad de usuarios transcurridos $12$ meses.
# 3.  Grafique la función, utilizando la librería *Matplotlib*, para los primeros dos años de funcionamiento.
# 4.  ¿Cuánto tiempo debe pasar para que la red social llegue a $800$ usuarios?

# %% [markdown]
# # Problema 8

# %%
import matplotlib.pyplot as plt
import numpy as np
from sympy import symbols , Eq , solve

def a(n):
    return (0.01*(n*n)) + (0.5*n) + 2

#1. Defina variable dependiente e independiente, indicando unidad de medida.
print("La variable independiente en este caso no es el tiempo sino la cantidad de datos a ordenar (n)\
    \n y la variable dependiente es el tiempo a(n) segundos")
#2. Determine el dominio contextualizado de la función.
print("El dominio contextualizado serian todos los reales mayores a 0")
#3. Determine el tiempo de ejecución para ordenar $1.200 elementos.
print(f"El tiempo de ejecucion para ordenar 1.200 elementos sera de: {a(1200)} segundos")
#4. Grafique, utilizando la biblioteca *Matplotlib*, la función A(n).
x_values=np.arange(0 , 10000 , 10)
y_values=a(x_values)
plt.plot(x_values , y_values)
plt.xlabel("Cantidad de datos")
plt.ylabel("Tiempo de ejecucion (segundos)")
plt.ticklabel_format(style="plain" , axis="y")
plt.show()
#5. ¿Cuántos elementos ordena luego de 6 horas de funcionamiento?
#en 6 horas hay 21.600 segundos

def b(time_on_seconds):
    n=symbols('n')
    equation = Eq( (0.01*(n*n)) + (0.5*n) + 2 , time_on_seconds )
    solutions = solve(equation , n)
    real_positive_solution = [s.evalf() for s in solutions if s.is_real and s>=0]
    return real_positive_solution


print(f"Luego de 6 horas de funcionamiento ordena un total de {b(21600)} elementos")
# Out:
# La variable independiente en este caso no es el tiempo sino la cantidad de datos a ordenar (n)
#  y la variable dependiente es el tiempo a(n) segundos
# El dominio contextualizado serian todos los reales mayores a 0
# El tiempo de ejecucion para ordenar 1.200 elementos sera de: 15002.0 segundos
# Luego de 6 horas de funcionamiento ordena un total de [1444.83842649456] elementos

# %% [markdown]
# El tiempo de ejecución de un algoritmo de ordenación (en segundos) se puede modelar mediante la función:
#
# $$A(n) = 0,01n^{2} + 0,5n + 2$$
#
# donde $n$ corresponde a la cantidad de elementos a ordenar. El algoritmo funciona desde las 23:00 horas hasta las 06:00 horas y debe ordenar $1.562$ elementos.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine el dominio contextualizado de la función.
# 3. Determine el tiempo de ejecución para ordenar $1.200$ elementos.
# 4. Grafique, utilizando la biblioteca *Matplotlib*, la función $A(n)$.
# 5. ¿Cuántos elementos ordena luego de $6$ horas de funcionamiento?

# %% [markdown]
# # Problema 9

# %%
import matplotlib.pyplot as plt
import numpy as np
from sympy import Eq , symbols , solve , log

def e(t): #t tiempo en horas
    return 50 *(np.log( t + 1 )) + 200

def d(kwh):
    t = symbols('t')
    equation = Eq(50 *(log( t + 1 )) + 200 , kwh )
    solutions = solve(equation , t)
    real_positive_solution = [s.evalf() for s in solutions if s.is_real and s>=0]
    return real_positive_solution

print("La variable independiente es el tiempo (t) en horas y la variable dependiente es el consumo de energia en kWh")

print(f"El consumo de energia del data center despues de 5 horas es de: {e(5)}")

print(f"El consumo sera de 350kWh cuando hayan pasado {d(350)} horas")

x_values=np.arange(1 , 100 , 10)
y_values=e(x_values)

plt.xlabel("Tiempo en horas")
plt.ylabel("Cantidad de kWh")
plt.plot(x_values , y_values)
plt.show()
# Out:
# La variable independiente es el tiempo (t) en horas y la variable dependiente es el consumo de energia en kWh
# El consumo de energia del data center despues de 5 horas es de: 289.5879734614027
# El consumo sera de 350kWh cuando hayan pasado [19.0855369231877] horas

# %% [markdown]
# El consumo de energía (en $kWh$) de un *Data Center* puede ser modelado por la función:
#
#  $$E(t) = 50\cdot \log(t + 1) + 200$$
#
# donde $t$ corresponde al tiempo (en horas) desde el inicio del monitoreo.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine el consumo de energía del *Data Center* después de $5$ horas.
# 3. ¿Luego de cuántas horas el consumo será de $350$ kWh?
# 4. Grafique, utilizando la biblioteca *Matplotlib*, la función $E(t)$.

# %% [markdown]
# # Problema 10

# %%
import matplotlib.pyplot as plt
import numpy as np
from sympy import Eq , solve , symbols , exp

def w(t): #t= tiempo en semanas
    return np.round((100 * np.exp(-0.1*t)) , 2)
    
def t(w):
    t = symbols("t")
    equation = Eq(100 * exp(-0.1*t) , w )
    solutions = solve(equation , t)
    return solutions

print("La variable independiente es e, tiempo en semanas (t) y la variable dependiente\
       es la carga del trabaho medido en porcentaje")

print(f"La carga del trabajo al inicio del proyecto sera de {w(0)}%")

print(f"La carga del trabajo transcurridas 4 semanas sera de {w(4)}%")

print(f"Si el proyecto durara 12 semanas la carga seria de un: {w(12)}% por lo tanto no, no llego al 20%")

print(f"para que la carga del trabajo sea de un 55% deberan pasar: {t(55)} semanas")

x_values=np.arange(1 , 13 , 1)
y_values=w(x_values)



plt.xticks(x_values)

plt.plot(x_values , y_values)
plt.show()
# Out:
# La variable independiente es e, tiempo en semanas (t) y la variable dependiente       es la carga del trabaho medido en porcentaje
# La carga del trabajo al inicio del proyecto sera de 100.0%
# La carga del trabajo transcurridas 4 semanas sera de 67.03%
# Si el proyecto durara 12 semanas la carga seria de un: 30.12% por lo tanto no, no llego al 20%
# para que la carga del trabajo sea de un 55% deberan pasar: [5.97837000755620] semanas

# %% [markdown]
# En gestión de proyectos, es crucial entender cómo se distribuye la carga de trabajo a lo largo del tiempo para planificar recursos, tiempo y esfuerzos de manera eficiente. Un fenómeno común es la disminución exponencial de la carga de trabajo, donde el esfuerzo requerido es mayor al inicio del proyecto y disminuye gradualmente a medida que se completan las tareas principales.
#
# Esta disminución exponencial puede modelarse matemáticamente para predecir y gestionar el trabajo de manera efectiva.
#
# <br>
#
# Un estudio sobre gestión de proyectos sostiene que la carga de trabajo en un proyecto (en porcentaje) puede ser modelada por la función:
#
# $$W(t) = 100e^{-0.1t}$$
#
# donde $t$ corresponde al tiempo transcurrido (en semanas) desde el inicio del proyecto.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine la carga de trabajo al inicio del proyecto.
# 3. ¿Cuál será la carga de trabajo luego de transcurridas $4$ semanas desde el inicio del proyecto?
# 4. Si el proyecto duró $12$ semanas, ¿es correcto afirmar que la carga de trabajo llegó al $20\%$?
# 5. ¿Cuántas semanas han pasado desde el inicio del proyecto para que la carga de trabajo sea de $55\%$?
# 6. Utilizando *Matplotlib*, grafique la función considerando un tiempo máximo de $12$ semanas.
